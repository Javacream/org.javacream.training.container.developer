# %% [markdown]
# # Lernpfad Container
#
#
# ## Voraussetzungen
#
# ### Technik
#
# * Das Seminar nutzt Docker

# %%
# !docker --version
# Out:
# Docker version 26.1.3, build 26.1.3-0ubuntu1~22.04.1

# %% [markdown]
# * Sinnvoll, aber nicht notwendig, ist die Benutzung von Visual Studio Code
#
# ![](attachment:image.png)
#
#
#   * ℹ️ Die Installation zusätzlicher Docker-PlugIns ist jedoch nicht notwendig

# %% [markdown]
# ## Inhalt
#
# * 3 Tage je 6h reine Seminarzeit
# * pro Tag jeweils 4 Unterrichtseinheiten zu 90 Minuten, insgesamt 12 Einheiten
#
# ### Block 1: Von Bare Metal zum Container
#
# * Vorstellung des Referenten
# * Vorstellung des Lernpfades, wo starten wir, wo geht die Reise hin?
# * Ein kurzer Abriss der Historie
#
# ### Block 2: First Contact
#
# * docker run als erstes Kommando
#   * ℹ️ Hier wird noch etwas unsauber gearbeitet und die transparente Erstellung des Containers hingenommen
# * Einführung des Docker Hub als Beispiel für eine Docker Registry
# * Erste Kommandos
#
# ### Block 3: Container im Detail: Die Sandbox
#
# * Schwerpunkt dieses Teils ist die Vermittlung der Tatsache, dass ein Container eigentlich ziemlich trivial ist: Ein Prozess, der auf dem Container-Dateisystem operiert
# * Zu Beginn nutzen wir das hello-world-Image, das ja im Wesentlichen nur ein executable enthält, was der export in ein Archiv beweist
# * Das Kopieren von Dateien in / aus dem Container kann hier bereits demostriert werden
# * Erst durch den Wechsel auf das nginx-Image können wir uns mit exec auf den laufenden Container verbinden und darin einen Shell-Prozess starten
# * ℹ️ Environments sowie die Kopplung mehrere Container wird auf docker compose verschoben
# * Port Mapping
# * Host Mounts
# * Volumes
#
# ### Block 4: Images
#
# * Image Dateisystem als union von Layern
# * Commit eines Containers-Dateisystems zum Layer eines neune Images
# * Ein erstes Dockerfile
#
# ### Block 5: Dockerfile und docker build
#
# * Dockerfile als Quellcode
# * Befehlsübersicht
# * Buildprozess
#   * ℹ️ Hier auch darauf eingehen, dass Layer und damit auch Images bei jedem Build eine neue ID bekommen werden. Zur Präsentation die Option --no-cache des build nutzen
#
# ### Block 6: Image Registries
#
# * Beispiel docker hub
# * Aufsetzen einer eigenen Image Registry, Beispiel Nexus
#   * Hinweis: Hierzu nutzen wir natürlich das Nexus Image
# * docker push
# * Tagging Best Practice
#
# ### Block 7: Developer Container
#
# * Aufbau eines Developer Containers
# * Beispiel: Developer Container und Visual Studio Code
# * Demonstrationen: Developer Container für Python und Java
# * Erzeugen angepasster Container
#
# ### Block 8: Image Modellierung
# * Image-Modellierung vs. Klassenmodellierung
# * Dockerfiles im Detail
# * Der Docker-Buildprozess revisited: Layer-Optimierung, BuildKit
# * Eine Hierachie z.B. für Java-Anwendungen
#
# ### Block 9: Build Container
#
# * Build-Pipelines
# * Bauen des Software-Artefakts in einem Build-Container
# * Problematik des Erzeugens eines Images in einem Build-Container
#
# ### Block 10: Workshop: Aufsetzen einer Build-Umgebung
# * Jenkins
# * GitLab CI/CD
#
# ### Block 11: Workshop: Ein komplettes Beispiel
# * Ein RESTful WebService z.B. auf Basis von Spring Boot
#
# ### Block 12: Abschluss
# * Zusammenfassung
# * Q&A
